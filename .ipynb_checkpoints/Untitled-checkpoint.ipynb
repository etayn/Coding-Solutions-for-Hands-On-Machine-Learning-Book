# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
(X_train , y_train) , (X_test , y_test) = keras.datasets.mnist.load_data()

# %%
X_train , X_val , y_train , y_val = train_test_split(X_train , y_train , train_size=0.8)

# %%
inputs = keras.layers.Input(shape=(28,28,1))
x = keras.layers.Rescaling(1./255)(inputs)
x = keras.layers.Conv2D(32 , 3 , activation = "relu")(x)
x = keras.layers.MaxPooling2D(pool_size = 2)(x)
x = keras.layers.Conv2D(64,3,activation = "relu")(x)
x = keras.layers.Flatten()(x)
x = keras.layers.Dropout(0.5)(x)
outputs = keras.layers.Dense(10 , activation = "softmax")(x)
model = keras.Model(inputs , outputs)

# %%
callbacks = [keras.callbacks.ModelCheckpoint(filepath="Models/q9_chapter14_covnet.keras" ,
                                           save_best_only=True,
                                           monitor = "val_loss")]
model.compile(loss= "sparse_categorical_crossentropy",
             optimizer = "adam" ,
             metrics = ["accuracy"])

# %%
history = model.fit(X_train , y_train , epochs=25 , batch_size=32 , validation_data = (X_val , y_val) ,
                   callbacks=callbacks)
# Out:
# Epoch 1/25
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0151 - accuracy: 0.9950 - val_loss: 0.0360 - val_accuracy: 0.9907
# Epoch 2/25
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0130 - accuracy: 0.9957 - val_loss: 0.0414 - val_accuracy: 0.9898
# Epoch 3/25
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0140 - accuracy: 0.9955 - val_loss: 0.0439 - val_accuracy: 0.9888
# Epoch 4/25
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0141 - accuracy: 0.9949 - val_loss: 0.0381 - val_accuracy: 0.9906
# Epoch 5/25
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.0129 - accuracy: 0.9955 - val_loss: 0.0415 - val_accuracy: 0.9890
# Epoch 6/25
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0127 - accuracy: 0.9954 - val_loss: 0.0398 - val_accuracy: 0.9904
# Epoch 7/25
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.0127 - accuracy: 0.9955 - val_loss: 0.0418 - val_accuracy: 0.9898
# Epoch 8/25
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.0126 - accuracy: 0.9960 - val_loss: 0.0447 - val_accuracy: 0.9893
# Epoch 9/25
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.0106 - accuracy: 0.9959 - val_loss: 0.0427 - val_accuracy: 0.9903
# Epoch 10/25
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.0107 - accuracy: 0.9962 - val_loss: 0.0390 - val_accuracy: 0.9897
# Epoch 11/25
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0096 - accuracy: 0.9962 - val_loss: 0.0443 - val_accuracy: 0.9894
# Epoch 12/25
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0097 - accuracy: 0.9969 - val_loss: 0.0412 - val_accuracy: 0.9906
# Epoch 13/25
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0088 - accuracy: 0.9970 - val_loss: 0.0506 - val_accuracy: 0.9893
# Epoch 14/25
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.0099 - accuracy: 0.9966 - val_loss: 0.0439 - val_accuracy: 0.9897
# Epoch 15/25
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.0085 - accuracy: 0.9972 - val_loss: 0.0480 - val_accuracy: 0.9903
# Epoch 16/25
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.0091 - accuracy: 0.9971 - val_loss: 0.0521 - val_accuracy: 0.9890
# Epoch 17/25
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.0084 - accuracy: 0.9971 - val_loss: 0.0507 - val_accuracy: 0.9894
# Epoch 18/25
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0081 - accuracy: 0.9972 - val_loss: 0.0521 - val_accuracy: 0.9892
# Epoch 19/25
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0089 - accuracy: 0.9969 - val_loss: 0.0490 - val_accuracy: 0.9898
# Epoch 20/25
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0084 - accuracy: 0.9974 - val_loss: 0.0501 - val_accuracy: 0.9894
# Epoch 21/25
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0073 - accuracy: 0.9974 - val_loss: 0.0541 - val_accuracy: 0.9891
# Epoch 22/25
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0095 - accuracy: 0.9970 - val_loss: 0.0524 - val_accuracy: 0.9882
# Epoch 23/25
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0079 - accuracy: 0.9973 - val_loss: 0.0524 - val_accuracy: 0.9903
# Epoch 24/25
# 1500/1500 [==============================] - 13s 9ms/step - loss: 0.0075 - accuracy: 0.9974 - val_loss: 0.0584 - val_accuracy: 0.9903
# Epoch 25/25
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0086 - accuracy: 0.9971 - val_loss: 0.0544 - val_accuracy: 0.9900

# %%
train_loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1 , len(train_loss) + 1)
plt.plot(epochs , train_loss , "b-" , label = "training loss")
plt.plot(epochs , val_loss , "b--", label = "validation loss")
plt.title("training and validation loss")
plt.legend()
plt.figure()
train_acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
plt.plot(epochs , train_acc , "b-" , label = "training accuracy")
plt.plot(epochs , val_acc , "b--", label = "validation accurcy")
plt.title("training and validation accuracy")
plt.legend()
plt.show()

# %%
test_model = keras.models.load_model("Models/q9_chapter14_covnet.keras")
test_model.evaluate(X_test , y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0317 - accuracy: 0.9912
# [0.031727053225040436, 0.9911999702453613]
